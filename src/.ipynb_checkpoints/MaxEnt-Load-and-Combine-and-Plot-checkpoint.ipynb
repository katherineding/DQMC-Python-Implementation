# %%
import numpy as np
import matplotlib.pyplot as plt
import os
user = os.environ.get('USER')

import data_analysis as da
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2

# %%
SMALL_SIZE = 14
MEDIUM_SIZE = 16
BIGGER_SIZE = 18

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
#plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
plotroot="hallplots/maxent/08_25_2020/"
resultroot="halldata/maxent/08_25_2020/"
#resultroot1="halldata/maxent/02_25_2020/"
#resultroot2="halldata/maxent/02_26_2020/"

# %%
Nx = "4"; Ny = "4"; nt = "0.125"; tp='0'; N = int(Nx) * int(Ny)
# if nt == "1.0":
#     nflux_list = ['0','1','4','8','12','16'];
# else:
#     nflux_list = ['0','1','2','3','4','6','8','12','16'];
nflux_list = ['4'];
nf_arr = np.array(list(map(float,nflux_list)))
B_arr = nf_arr/N
nF = len(nflux_list)
tt_prefix = f"{Nx}x{Ny} t'={tp} n={nt}"

# %%
for k in range(nF):
    nflux = nflux_list[k]
    pathroot = f"/home/{user}/Documents/GradWork/Devereaux/Data-DQMC/{Nx}x{Ny}/nflux{nflux}/n{nt}/"
    plt.figure();
    plt.title(tt_prefix + f" nflux={nflux_list[k]}")
    betas_list, Us_list, mu_dict = da.readmu(pathroot,"best_mu.txt",show=True)
    plt.show()

if nt == "0.95" or nt == "1.0":
    pathroot = f"/home/{user}/Documents/GradWork/Devereaux/Data-DQMC/{Nx}x{Ny}/nflux1/n{nt}/"      
else:
    pathroot = f"/home/{user}/Documents/GradWork/Devereaux/Data-DQMC/{Nx}x{Ny}/nflux2/n{nt}/"  
betas_list, Us_list, mu_dict = da.readmu(pathroot,"best_mu.txt",show=False)
nT = len(betas_list); nU = len(Us_list)
beta_list = np.array(list(map(float,betas_list)))
U_list = np.array(list(map(float,Us_list)))
border = np.argsort(beta_list); Uorder = np.argsort(U_list)
# Out:
# mu info source: /home/jxding/Documents/GradWork/Devereaux/Data-DQMC/6x6/nflux0/n1.0/best_mu.txt
# target filling = 1.0
# beta list = ['0.5', '0.7', '1.5', '1', '2', '3', '4']
# U list = ['0', '10', '12', '16', '4', '8']
# mu info source: /home/jxding/Documents/GradWork/Devereaux/Data-DQMC/6x6/nflux1/n1.0/best_mu.txt
# target filling = 1.0
# beta list = ['0.5', '0.7', '1.5', '1', '2', '3', '4']
# U list = ['0', '10', '12', '16', '4', '8']
# mu info source: /home/jxding/Documents/GradWork/Devereaux/Data-DQMC/6x6/nflux4/n1.0/best_mu.txt
# target filling = 1.0
# beta list = ['0.5', '0.7', '1.5', '1', '2', '3', '4']
# U list = ['0', '10', '12', '16', '4', '8']
# mu info source: /home/jxding/Documents/GradWork/Devereaux/Data-DQMC/6x6/nflux8/n1.0/best_mu.txt
# target filling = 1.0
# beta list = ['0.5', '0.7', '1.5', '1', '2', '3', '4']
# U list = ['0', '10', '12', '16', '4', '8']
# mu info source: /home/jxding/Documents/GradWork/Devereaux/Data-DQMC/6x6/nflux12/n1.0/best_mu.txt
# ...

# %%
print("nflux_list:",nflux_list)
print("betas_list:",betas_list)
print("Us_list:",Us_list)
# Out:
# nflux_list: ['0', '1', '4', '8', '12', '16']
# betas_list: ['0.5', '0.7', '1.5', '1', '2', '3', '4']
# Us_list: ['0', '10', '12', '16', '4', '8']

# %%
print(Uorder)
Umask = [False, True, False, True, False, True, False]
# Out:
# [0 4 5 1 2 3]

# %% [markdown]
# # xx Conductivity

# %%
sigxx_ld = np.load(resultroot+f"Nx{Nx}_Ny{Ny}_n{nt}_tp{tp}_sigxx.npy")
halfomega_ld = np.load(resultroot+f"Nx{Nx}_Ny{Ny}_n{nt}_tp{tp}_halfomega.npy")
halfdomega_ld = np.load(resultroot+f"Nx{Nx}_Ny{Ny}_n{nt}_tp{tp}_halfdomega.npy")
num_ok = np.count_nonzero(~np.isnan(sigxx_ld))
print(f"{int(num_ok)}/{sigxx_ld.size} = {int(num_ok)/sigxx_ld.size:.3g} of data is saved in directory {resultroot}")
print(f"sigxx_ld.shape = {sigxx_ld.shape} =? ({nT},{nU},{nF}, bs, {nw}//2) ")
print(f"halfomega_ld.shape = {halfomega_ld.shape}")
bs_xx = sigxx_ld.shape[3]
nw = sigxx_ld.shape[4]*2
# Out:
# 7082800/10080000 = 0.703 of data is saved in directory halldata/maxent/06_20_2020/
# sigxx_ld.shape = (7, 6, 6, 200, 200) =? (7,6,6, bs, 400//2)
# halfomega_ld.shape = (7, 6, 6, 200)

# %% [markdown]
# ## Zero Frequency xx conductivity bootstrap hisogram

# %%
for k in range(2,nF):
    nflux = nflux_list[k]
    pathroot = f"/home/{user}/Documents/GradWork/Devereaux/Data-DQMC/{Nx}x{Ny}/nflux{nflux}/n{nt}/"
    _, _, mu_dict = da.readmu(pathroot,"best_mu.txt")
    for j in Uorder[1:]:
        Us = Us_list[j]
        for i in border:
            betas = betas_list[i]
            try:
                mu = mu_dict[(betas,Us)]
            except KeyError as e:
                print(e)
                continue
            path = pathroot + f"beta{betas}_U{Us}_mu{mu:.3f}/"
            try:
                plt.figure()
                plt.title(tt_prefix + f" nflux={nflux} beta={betas} U={Us} bs={bs_xx}")
                plt.hist(sigxx_ld[i,j,k,:,0],bins=20)
                plt.xlabel(r"$\sigma_{xx}(\omega=0)$ distribution")
                plt.ylabel(r"counts")
                plt.show()
            except ValueError as e:
                print(e) 
                continue
# Out:
# mu info source: /home/jxding/Documents/GradWork/Devereaux/Data-DQMC/6x6/nflux4/n1.0/best_mu.txt
# /home/jxding/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/jxding/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-54-569960c938f8> in <module>
#      19                 plt.xlabel(r"$\sigma_{xx}(\omega=0)$ distribution")
#      20                 plt.ylabel(r"counts")
# ---> 21                 plt.show()
#      22             except ValueError as e:
#      23                 print(e)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     270     """
# ...

# %% [markdown]
# ## Optical xx Conductivity Bootstrap

# %%
for k in range(0,nF):
    nflux = nflux_list[k];
    for j in Uorder[1:]:
        U_s = Us_list[j]
        for i in border:
            beta_s = betas_list[i]
            w = halfomega_ld[i,j,k,:]
            plt.figure();
            plt.title(tt_prefix + f" nflux={nflux} beta={beta_s} U={U_s} bs = {bs_xx}")
            plt.plot(w,sigxx_ld[i,j,k,:,:].T,color='k',lw=1)
            plt.grid(True)
            plt.ylabel(r"$\sigma_{xx}(\omega)$")
            plt.xlabel(r"real frequency $\omega$")
            plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-bfd8a158b35e> in <module>
#      12             plt.ylabel(r"$\sigma_{xx}(\omega)$")
#      13             plt.xlabel(r"real frequency $\omega$")
# ---> 14             plt.show()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     270     """
#     271     global _show
# --> 272     return _show(*args, **kw)
#     273
#     274
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in _fetch_figure_metadata(fig)
# ...

# %% [markdown]
# ## Plot $\sigma_{xx}(\omega = 0)$

# %%
colors = plt.cm.plasma(np.linspace(0,1,nF))
for j in Uorder[1:]:
    U_s = Us_list[j]
    plt.figure();
    plt.title(tt_prefix + f" U={U_s} bs={bs_xx}")
    n=0
    for k in range(nF):
        nflux = nflux_list[k];
        xx = sigxx_ld[:,j,k,:,0]
        plt.errorbar(1/beta_list[border],np.nanmean(xx,axis=1)[border],\
                     yerr = np.nanstd(xx,axis=1)[border], 
                     fmt="^:",label=f"B={nflux}/{N}")
        n+=1
    plt.ylabel(r"Re[$\sigma_{xx}(\omega = 0)$] [$e^2/\hbar$]")
    plt.xlabel(r"temperature $T/t$")
    plt.grid(True)
    plt.xlim(0,2.2)
    plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
    plt.savefig(f'{plotroot}{Nx}x{Ny}_tp{tp}_n{nt}_U{U_s}_condxx.png',dpi=300,bbox_inches="tight")
# Out:
# /home/jxding/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: Mean of empty slice
#   # Remove the CWD from sys.path while we load stuff.
# /home/jxding/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1667: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)

# %% [markdown]
# # xy conductivity

# %%
sigxx2_ld = np.load(resultroot+f"Nx{Nx}_Ny{Ny}_n{nt}_tp{tp}_sigxx2.npy")
chi2_ld = np.load(resultroot+f"Nx{Nx}_Ny{Ny}_n{nt}_tp{tp}_chi2.npy")
sigxy_ld = np.load(resultroot+f"Nx{Nx}_Ny{Ny}_n{nt}_tp{tp}_sigxy.npy")
omega_ld = np.load(resultroot+f"Nx{Nx}_Ny{Ny}_n{nt}_tp{tp}_omega.npy")
domega_ld = np.load(resultroot+f"Nx{Nx}_Ny{Ny}_n{nt}_tp{tp}_domega.npy")
num_ok = np.count_nonzero(~np.isnan(sigxy_ld))
print(f"{int(num_ok)}/{sigxy_ld.size} = {int(num_ok)/sigxy_ld.size:.3g} of data is saved in directory {resultroot}")
print(f"sigxy_ld.shape = {sigxy_ld.shape} =? ({nT},{nU},{nF}, bs) ")
print(f"omega_ld.shape = {omega_ld.shape}")
bs_xy = sigxy_ld.shape[3]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-36-bde8e65a3321> in <module>
# ----> 1 sigxx2_ld = np.load(resultroot+f"Nx{Nx}_Ny{Ny}_n{nt}_tp{tp}_sigxx2.npy")
#       2 chi2_ld = np.load(resultroot+f"Nx{Nx}_Ny{Ny}_n{nt}_tp{tp}_chi2.npy")
#       3 sigxy_ld = np.load(resultroot+f"Nx{Nx}_Ny{Ny}_n{nt}_tp{tp}_sigxy.npy")
#       4 omega_ld = np.load(resultroot+f"Nx{Nx}_Ny{Ny}_n{nt}_tp{tp}_omega.npy")
#       5 domega_ld = np.load(resultroot+f"Nx{Nx}_Ny{Ny}_n{nt}_tp{tp}_domega.npy")
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     426         own_fid = False
#     427     else:
# --> 428         fid = open(os_fspath(file), "rb")
#     429         own_fid = True
#     430
#
# ...

# %% [markdown]
# ## Plot $\sigma_{xy}(\omega = 0)$

# %%
colors = plt.cm.inferno(np.linspace(0,1,nF))
for j in Uorder[1:]:
    U_s = Us_list[j]
    plt.figure();
    plt.title(tt_prefix +f" U={U_s} bs={bs_xy}")
    n=0
    for k in range(2,nF):
        nflux = nflux_list[k];
        yy = sigxy_ld[:,j,k,:]
        plt.errorbar(1/beta_list[border],np.nanmean(yy,axis=1)[border],\
                     yerr = np.nanstd(yy,axis=1)[border], 
                     fmt="^:",color = colors[n],label=f"nflux={nflux}")
        n+=1
    plt.xlabel(r"temperature $T/t$")
    plt.ylabel(r"$\sigma_{xy}(\omega = 0)$ [$e^2/\hbar$]")
    plt.grid(True)
    plt.xlim(0,8.2)
    plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
    plt.savefig(f'{plotroot}{Nx}x{Ny}_tp{tp}_n{nt}_U{U_s}_condxy.png',dpi=300,bbox_inches="tight")
# Out:
# /home/jxding/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: Mean of empty slice
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# ## Hall Coefficient $R_H$

# %%
colors = plt.cm.plasma(np.linspace(0,1,nF))
for j in Uorder[1:]:
    plt.figure()
    plt.title(tt_prefix + f" U={Us_list[j]}")
    n=0
    for k in range(1,nF-2):
        xy = sigxy_ld[:,j,k,:]
        xx = sigxx_ld[:,j,k,:,0]
        mxy = np.nanmean(xy,axis=1)
        nf = nf_arr[k]
        mxx = np.nanmean(xx,axis=1)
        print(np.sqrt(np.var(xy,axis=1) + np.var(np.power(xx,2),axis=1))*(mxy/(mxx**2))*N/nf/(2*np.pi))
        plt.errorbar(1/beta_list[border],((mxy/(mxx**2))*N/nf/(2*np.pi))[border],\
                     yerr = (np.sqrt(np.var(xy,axis=1) + np.var(np.power(xx,2),axis=1))*(mxy/(mxx**2))*N/nf/(2*np.pi))[border],\
                     fmt = '.--',color=colors[n],label= f"nflux = {nflux_list[k]}")
        n+=1
    plt.xlabel(r"temperature $T/t$")
    plt.ylabel(r"$R_{H}$ [$a^2/e$]")
    plt.axhline(y=0,color='k',lw=1)
    plt.grid(True)
    plt.xlim(0,8.2)
    plt.ylim(-0.03,0.03)
    plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
    plt.savefig(f'{plotroot}{Nx}x{Ny}_tp{tp}_n{nt}_U{Us_list[j]}_RH.png',dpi=300,bbox_inches="tight")
# Out:
# /home/jxding/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: RuntimeWarning: Mean of empty slice
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-56e2dec34dcd> in <module>
#      10         nf = nf_arr[k]
#      11         mxx = np.nanmean(xx,axis=1)
# ---> 12         print(np.sqrt(np.var(xy,axis=1) + np.var(np.power(xx,2),axis=1))*(mxy/(mxx**2))*N/nf/(2*np.pi))
#      13         plt.errorbar(1/beta_list[border],((mxy/(mxx**2))*N/nf/(2*np.pi))[border],\
#      14                      yerr = (np.sqrt(np.var(xy,axis=1) + np.var(np.power(xx,2),axis=1))*(mxy/(mxx**2))*N/nf/(2*np.pi))[border],\
#
# ValueError: operands could not be broadcast together with shapes (9,) (8,)

# %% [markdown]
# ## $\rho_{xx}(B)|_{\omega=0}$ as function of $B$ field. Not included xy contribution yet.

# %%
for i in border:
    beta_s = betas_list[i]
    plt.figure();
    plt.title(tt_prefix +fr" $\beta$={beta_s} bs={bs_xx}")
    for j in Uorder[1:]:
        U_s = Us_list[j]
        xx = sigxx_ld[i,j,:,:,0]
        mxx = np.nanmean(xx,axis=1)
        exx = np.nanstd(xx,axis=1)
        rxx = exx/mxx #relative error
        #print(np.nanstd(1/xx,axis=1),rxx/mxx)
        #plt.errorbar(B_arr,1/mxx,yerr = np.nanstd(1/xx,axis=1), fmt="^:",label=f"U={U_s} 1")
        plt.errorbar(B_arr,1/mxx,yerr = rxx*1/mxx, fmt="s:",label=f"U={U_s}")
    plt.xlabel(r"B [$\Phi_0/a^2$]")
    plt.ylabel(r"$\rho_{xx}(\omega = 0)$  [$\hbar/e^2$]")
    #plt.ylim(0,10)
    #plt.xlim(-0.01,0.25)
    plt.grid(True)
    plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
    plt.savefig(f'{plotroot}{Nx}x{Ny}_tp{tp}_n{nt}_beta{beta_s}_rhoxx.png',dpi=300,bbox_inches="tight")
# Out:
# /home/jxding/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: Mean of empty slice

# %% [markdown]
# ## Magnetoresistance as function of $B$ field. Not included xy contribution yet.

# %%
for i in border[2:]:
    beta_s = betas_list[i]
    plt.figure();
    plt.title(tt_prefix +fr" $\beta$={beta_s} bs={bs_xx}")
    for j in Uorder[1:]:
        U_s = Us_list[j]
        sxx = sigxx_ld[i,j,:,:,0]
        mxx = np.nanmean(sxx,axis=1)
        #zero field
        s0 = sxx[0,:]
        m0 = np.nanmean(s0)
        re0 = np.nanstd(s0)/m0
        #some field
        sB = sxx[1:,:]
        mB = np.nanmean(sB,axis=1)
        reB = np.nanstd(sB,axis=1)/mB
        #print("finite field errors",reB)
        #print("zero frequency errors",re0)
        retotal = np.sqrt(np.power(reB,2)+np.power(re0,2))
        #print("total relative errors",retotal,retotal.shape)
        retotal = np.insert(retotal,0,re0)
        #print("total relative errors",retotal,retotal.shape,"\n")
        MRB = s0/sxx - 1
        MRm = np.nanmean(MRB,axis=1)
        plt.errorbar(B_arr ,MRm, yerr = retotal*(mxx/m0), fmt="^--",label=f"U={U_s}")
        plt.axhline(y=0,lw=1,color='k')
    plt.xlabel(r"B [$\Phi_0/a^2$]")
    plt.ylabel("MR(B)")
    #plt.grid(True)
    plt.ylim(-0.05,1)
    plt.xlim(-0.01,0.25)
    plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
    plt.savefig(f'{plotroot}{Nx}x{Ny}_tp{tp}_n{nt}_beta{beta_s}_MR.png',dpi=300,bbox_inches="tight")
# Out:
# /home/jxding/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: Mean of empty slice
#
# /home/jxding/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: RuntimeWarning: Mean of empty slice
#   from ipykernel import kernelapp as app
# /home/jxding/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: Mean of empty slice
# /home/jxding/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: Mean of empty slice
#   # This is added back by InteractiveShellApp.init_path()
