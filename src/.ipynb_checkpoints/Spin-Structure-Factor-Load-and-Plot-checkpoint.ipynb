# %%
import numpy as np
import matplotlib.pyplot as plt
import os
user = os.environ.get('USER')
import data_analysis as da
import spin_struct
# %load_ext autoreload
from itertools import product

# %%
# %autoreload 2

# %%
plotroot="hallplots/spin-struct-fact/"
resultroot="halldata/spin-struct-fact/"

# %%
SMALL_SIZE = 14
MEDIUM_SIZE = 16
BIGGER_SIZE = 18

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
#plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
Nx = "6"; Ny = "6"; nt = "0.85"; tp='0'; N = int(Nx) * int(Ny)
nflux_list = ['0','1','2','3','4','6','8']
nf_arr = np.array(list(map(float,nflux_list)))
nF = len(nflux_list)
tt_prefix = f"{Nx}x{Ny} t'={tp} n={nt}"

# %%
for k in range(nF):
    nflux = nflux_list[k]
    pathroot = f"/home/{user}/Documents/GradWork/Devereaux/Data-DQMC/{Nx}x{Ny}/nflux{nflux}/n{nt}/"
    plt.figure();
    plt.title(tt_prefix + f" nflux={nflux_list[k]}")
    betas_list, Us_list, mu_dict = da.readmu(pathroot,"best_mu.txt",show=True)
    plt.show()
    
if nt == "0.95" or nt == "1.0":
    pathroot = f"/home/{user}/Documents/GradWork/Devereaux/Data-DQMC/{Nx}x{Ny}/nflux1/n{nt}/"      
else:
    pathroot = f"/home/{user}/Documents/GradWork/Devereaux/Data-DQMC/{Nx}x{Ny}/nflux2/n{nt}/"  
betas_list, Us_list, mu_dict = da.readmu(pathroot,"best_mu.txt",show=False)
nT = len(betas_list); nU = len(Us_list)
beta_list = np.array(list(map(float,betas_list)))
U_list = np.array(list(map(float,Us_list)))
border = np.argsort(beta_list); Uorder = np.argsort(U_list)
# Out:
# mu info source: /home/jxding/Documents/GradWork/Devereaux/Data-DQMC/6x6/nflux0/n0.85/best_mu.txt
# target filling = 0.85
# beta list = ['0.125', '0.25', '0.5', '0.7', '1.5', '1', '2', '3', '4']
# U list = ['0.5', '0', '1', '10', '12', '16', '2', '4', '8', '6']
# mu info source: /home/jxding/Documents/GradWork/Devereaux/Data-DQMC/6x6/nflux1/n0.85/best_mu.txt
# target filling = 0.85
# beta list = ['0.125', '0.25', '0.5', '0.7', '1.5', '1', '2', '3', '4']
# U list = ['0.5', '0', '1', '10', '12', '16', '2', '4', '8', '6']
# mu info source: /home/jxding/Documents/GradWork/Devereaux/Data-DQMC/6x6/nflux2/n0.85/best_mu.txt
# target filling = 0.85
# beta list = ['0.5', '0.7', '1.5', '1', '2', '3', '0.125', '0.25']
# U list = ['0', '10', '12', '16', '4', '6', '8']
# KeyError: ('0.125', '0')
# KeyError: ('0.25', '0')
# mu info source: /home/jxding/Documents/GradWork/Devereaux/Data-DQMC/6x6/nflux3/n0.85/best_mu.txt
# target filling = 0.85
# ...

# %%
print("nflux_list:",nflux_list)
print("betas_list:",betas_list)
print("Us_list:",Us_list)
# Out:
# nflux_list: ['0', '1', '2', '3', '4', '6', '8']
# betas_list: ['0.5', '0.7', '1.5', '1', '2', '3', '0.125', '0.25']
# Us_list: ['0', '10', '12', '16', '4', '6', '8']

# %%
data_ld = np.load(resultroot+f"Nx{Nx}_Ny{Ny}_n{nt}_tp{tp}_S.npy")
omega_ld = np.load(resultroot+f"Nx{Nx}_Ny{Ny}_n{nt}_tp{tp}_Somega.npy")
domega_ld = np.load(resultroot+f"Nx{Nx}_Ny{Ny}_n{nt}_tp{tp}_Sdomega.npy")
num_ok = np.count_nonzero(~np.isnan(data_ld))
print(f"{int(num_ok)}/{data_ld.size} = {int(num_ok)/data_ld.size:.3g} of data is saved in directory {resultroot}")
print(f"S_ld.shape = {data_ld.shape}")
bs = data_ld.shape[3]; nw = data_ld.shape[-1]
dim_x = data_ld.shape[4];dim_y = data_ld.shape[5]
assert dim_x == dim_y
# Out:
# 144000/1254400 = 0.115 of data is saved in directory halldata/spin-struct-fact/
# S_ld.shape = (8, 7, 7, 1, 4, 4, 200)

# %%
A = np.random.rand(dim_x,dim_y)
print(A)
i_00_pi0_inc = np.ones(dim_y,dtype=int)*(dim_x-1)
j_00_pi0_inc = np.arange(dim_y)
i_pi0_pipi_noinc = np.arange(dim_x-2,0,-1)
j_pi0_pipi_noinc = np.ones(dim_x-2,dtype=int)*(dim_y-1)
i_pipi_00_inc = np.arange(dim_x)
j_pipi_00_inc = np.arange(dim_x-1,-1,-1) #assumed dim_x == dim_y
i_total = np.concatenate((i_00_pi0_inc,i_pi0_pipi_noinc,i_pipi_00_inc))
j_total = np.concatenate((j_00_pi0_inc,j_pi0_pipi_noinc,j_pipi_00_inc))
i_plot = np.concatenate((i_pipi_00_inc[:-1],i_00_pi0_inc))
j_plot = np.concatenate((j_pipi_00_inc[:-1],j_00_pi0_inc))
assert i_total.shape == j_total.shape
print(A[i_total,j_total])
print(A[i_plot,j_plot])
# Out:
# [[0.329 0.283 0.465 0.555]
#  [0.261 0.423 0.57  0.319]
#  [0.533 0.551 0.29  0.2  ]
#  [0.978 0.61  0.068 0.795]]
# [0.978 0.61  0.068 0.795 0.2   0.319 0.555 0.57  0.551 0.978]
# [0.555 0.57  0.551 0.978 0.61  0.068 0.795]

# %%
for j in Uorder[1:]:
    U_s = Us_list[j]
    for i in border[6:]:
        beta_s = betas_list[i]
        for k in range(nF):
            nflux=nflux_list[k]
            w = omega_ld[i,j,k]
            dw = domega_ld[i,j,k]
            S_collect = np.full((i_plot.shape[0],nw),np.nan)
            for n in range(len(i_plot)):
                qi = i_plot[n]
                qj = j_plot[n]
                S_collect[n,:] = data_ld[i,j,k,0,qi,qj,:]
            plt.figure()
            plt.title(tt_prefix + f" beta={beta_s} U={U_s} nflux= {nflux}")
            #weird x axis and y axis prepend/appends to work with pcolormesh function
            if np.all(np.isnan(S_collect)):
                continue
            plt.pcolormesh( np.insert(w,0,-dw[0]/2), np.arange(len(i_plot)+1), S_collect,cmap="inferno")
            plt.xlim(0,4)
            #plt.imshow(np.nan_to_num(S_collect,0),aspect='auto')
            plt.yticks([0+0.5,dim_y-1+0.5,dim_x+dim_y-2+0.5],\
                       labels=[r"$(\pi,\pi)$","(0,0)",r"$(\pi,0)$"])
            #plt.xticks([0,nw//4,nw//2,nw*3//4,nw-1],labels=["0",f"np.sum(dw[:nw//4])",r"$(\pi,0)$","(0,0)"])
            plt.colorbar()
        #plt.grid(True)
        #plt.ylabel(r"dos$(\omega)$")
            plt.xlabel(r"$\omega/t$")
        #plt.xlim(-12,12)
        #plt.ylim(-0.02,1.05)
        #plt.axvline(x=0,color='k',lw=2,ls=":")
        #plt.gca().axes.get_yaxis().set_visible(False)
        #plt.legend(loc="best")
            #plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
            plt.savefig(f'{plotroot}{Nx}x{Ny}_tp{tp}_n{nt}_beta{beta_s}_U{U_s}_nflux{nflux}_spin_sus_new.png',dpi=300,bbox_inches="tight")
            plt.show()
        #plt.show()
