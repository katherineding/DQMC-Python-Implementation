# %%
def cmplx_fmt(z):
    if z.imag == 0.0:
        return f"{z.real:+g}"
    elif z.real == 0.0:
        return f"{z.imag:+g}i"
    else:
        return f"({z.real:+g}{z.imag:+g}i)"
class c:
    '''c operator (fermionic)'''
    spin = "u"
    label = ""
    dag = False
    def __init__(self, spin, label, dag=False):
        self.spin = str(spin)
        self.label = str(label)
        self.dag = bool(dag)
    def __lt__(self, other):
        return self.dag < other.dag or self.spin > other.spin or self.label < other.label
    def __eq__(self, other):
        return self.dag == other.dag and self.spin == other.spin and self.label == other.label
    def __str__(self):
        str_spin = r"\uparrow" if self.spin == "u" else r"\downarrow" if self.spin == "d" else self.spin
        str_dag = r"^{\dagger}" if self.dag else ""
        return f"c_{{{str_spin} {self.label}}}{str_dag}"
    def __add__(self, other):
        return exp(self) + exp(other)
    def __radd__(self, other):
        return exp(other) + exp(self)
    def __sub__(self, other):
        return exp(self) - exp(other)
    def __rsub__(self, other):
        return exp(other) - exp(self)
    def __mul__(self, other):
        if type(other) is cp:
            return cp(self) * other
        if type(other) is c:
            return cp(self) * cp(other)
        try:
            return exp(self) * exp(other)
        except NotImplementedError:
            return NotImplemented
    def __rmul__(self, other):
        return exp(other) * exp(self)
class cp:
    '''product of c operators'''
    cs = []
    def __init__(self, x):
        if type(x) is c:
            self.cs = [x]
        elif type(x) is cp:
            self.cs = x.cs
        elif type(x) is list:
            self.cs = x
    def __lt__(self, other):
        return self.cs < other.cs
    def __eq__(self, other):
        return self.cs == other.cs
    def __str__(self):
        return " ".join([str(o) for o in self.cs])
    def __add__(self, other):
        return exp(self) + exp(other)
    def __radd__(self, other):
        return exp(other) + exp(self)
    def __sub__(self, other):
        return exp(self) - exp(other)
    def __rsub__(self, other):
        return exp(other) - exp(self)
    def __mul__(self, other):
        if type(other) is cp:
            return cp(self.cs + other.cs)
        if type(other) is c:
            return self * cp(other)
        try:
            return exp(self) * exp(other)
        except NotImplementedError:
            return NotImplemented
    def __rmul__(self, other):
        return exp(other) * exp(self)
    def _wick(self):
        w = exp([])
        for i in range(1, len(self.cs)):
            if self.cs[0].spin == self.cs[i].spin and self.cs[0].dag != self.cs[i].dag:
                p = 1.0 if i % 2 == 1 else -1.0
                if len(self.cs) == 2:
                    w = w + p*self.cs[0]*self.cs[i]
                else:
                    w = w + p*self.cs[0]*self.cs[i]*cp(self.cs[1:i] + self.cs[i+1:])._wick()
        return w
    def wickstr(self):
        def grnstr(a, b):
            spnstr = r"\uparrow" if a.spin == "u" else r"\downarrow" if a.spin == "d" else a.spin
            if (not a.dag) and b.dag:
                return f"g_{{{a.label} {b.label}}}^{{{spnstr}}}"
            elif a.dag and (not b.dag):
                deltastr = fr"\delta_{{{a.label} {b.label}}}" if a.label < b.label \
                           else fr"\delta_{{{b.label} {a.label}}}" if b.label < a.label \
                           else "1"
                return f"({deltastr} - g_{{{b.label} {a.label}}}^{{{spnstr}}})"
        w = self._wick().simplify()
        return "\n".join([("+" if x == 1.0 else "-" if x == -1.0 else cmplx_fmt(x)) + " ".join([grnstr(a, b) for a, b in zip(o.cs[::2], o.cs[1::2])]) for x, o in w.terms])
    def wickcode(self):
        def grnstr(a, b):
            if (not a.dag) and b.dag:
                return f"g{a.spin}{a.label}{b.label}"
            elif a.dag and (not b.dag):
                return f"h{a.spin}{b.label}{a.label}"
            else:
                raise RuntimeError
        w = self._wick().simplify()
        return "".join([("+" if x == 1.0 else "-" if x == -1.0 else cmplx_fmt(x)) + "*".join([grnstr(a, b) for a, b in zip(o.cs[::2], o.cs[1::2])]) for x, o in w.terms])
class exp:
    '''expression'''
    terms = []
    def __init__(self, x):
        if type(x) in (int, float, complex):
            self.terms = [[x, cp([])]]
        elif type(x) in (c, cp):
            self.terms = [[1.0, cp(x)]]
        elif type(x) is list:
            self.terms = x
        elif type(x) is exp:
            self.terms = x.terms
        else:
            print("wtf", x, type(x))
            raise NotImplementedError
    def __str__(self):
        return "\\\\\n".join([f"{cmplx_fmt(x)} {o}" for x, o in self.terms])
    def __add__(self, other):
        if type(other) is exp:
            return exp(self.terms + other.terms)
        else:
            return self + exp(other)
    def __radd__(self, other):
        return exp(other) + self
    def __sub__(self, other):
        return self + -1.0*other
    def __rsub__(self, other):
        return other + -1.0*self
    def __mul__(self, other):
        if type(other) is exp:
            return exp([[x[0]*y[0], x[1]*y[1]] for x in self.terms for y in other.terms])
        try:
            return self * exp(other)
        except NotImplementedError:
            return NotImplemented
    def __rmul__(self, other):
        return exp(other) * self
    def simplify(self):
        if len(self.terms) == 0:
            return exp([])
        sort_terms = sorted(self.terms, key=lambda t: t[1])
        simp_terms = [sort_terms[0][:]]
        for t in sort_terms[1:]:
            if simp_terms[-1][1] == t[1]:
                simp_terms[-1][0] += t[0]
            else:
                simp_terms.append(t[:])
        return exp([t for t in simp_terms if t[0] != 0.0])
    def wickstr(self):
        wicks = [(x, o.wickstr()) for x, o in self.terms]
        return "\\\\\n".join([f"{cmplx_fmt(x)} (\n{w}\n)" for x, w in wicks if w != ""])
    def wickcode(self):
        wicks = [(x, o.wickcode()) for x, o in self.terms]
        return "\n".join([f"{cmplx_fmt(x)}*({w})" for x, w in wicks if w != ""])
class vec:
    '''3-vector'''
    x, y, z = 0.0, 0.0, 0.0
    def __init__(self, x, y, z):
        self.x, self.y, self.z = x, y, z
    def __str__(self):
        return f"({self.x})\hat{{x}}\n+({self.y})\hat{{y}}\n+({self.z})\hat{{z}}"
    def __add__(self, other):
        if type(other) is vec:
            return vec(self.x + other.x, self.y + other.y, self.z + other.z)
        return NotImplemented
    def __sub__(self, other):
        if type(other) is vec:
            return vec(self.x - other.x, self.y - other.y, self.z - other.z)
        return NotImplemented
    def __mul__(self, other):
        if type(other) is vec:
            raise TypeError
        return vec(self.x * other, self.y * other, self.z * other)
    def __rmul__(self, other):
        if type(other) is vec:
            raise TypeError
        return vec(other * self.x, other * self.y, other * self.z)
    def dot(self, other):
        return (self.x * other.x) + (self.y * other.y) + (self.z * other.z)
    def cross(self, other):
        return vec(self.y * other.z - self.z * other.y,
                   self.z * other.x - self.x * other.z,
                   self.x * other.y - self.y * other.x)

# %%
def spin(label):
    cud = c("u", label, 1)
    cdd = c("d", label, 1)
    cu = c("u", label)
    cd = c("d", label)
    return vec(cud*cd + cdd*cu, -1j*cud*cd + 1j*cdd*cu, cud*cu - cdd*cd)

def den(label):
    cud = c("u", label, 1)
    cdd = c("d", label, 1)
    cu = c("u", label)
    cd = c("d", label)
    return cud*cu + cdd*cd

def hden(label):
    cud = c("u", label, 1)
    cdd = c("d", label, 1)
    cu = c("u", label)
    cd = c("d", label)
    return cu*cud + cd*cdd

def hole(label):
    cud = c("u", label, 1)
    cdd = c("d", label, 1)
    cu = c("u", label)
    cd = c("d", label)
    return cu*cud*cd*cdd

# %%
ss = (hden("h") * spin("i").z * spin("j").z).simplify()
# ss = (c("u", "h", 1) * c("u", "h") * spin("i").x * spin("j").x).simplify()
# ss = (1*c("u", "h", 1) * c("u", "h") * c("u", "i", 1) * c("d", "i") * c("d", "i", 1) * c("u", "j")).simplify()
print(ss.wickcode())
# Out:
# +1*(+guhh*huii*hujj+guhh*huji*guij-guhi*huih*hujj-guhi*hujh*guij+guhj*huih*huji-guhj*hujh*huii)
# -1*(+guhh*huii*hdjj-guhi*huih*hdjj)
# -1*(+guhh*hdii*hujj-guhj*hujh*hdii)
# +1*(+guhh*hdii*hdjj+guhh*hdji*gdij)
# +1*(+gdhh*huii*hujj+gdhh*huji*guij)
# -1*(+gdhh*huii*hdjj-gdhj*hdjh*huii)
# -1*(+gdhh*hdii*hujj-gdhi*hdih*hujj)
# +1*(+gdhh*hdii*hdjj+gdhh*hdji*gdij-gdhi*hdih*hdjj-gdhi*hdjh*gdij+gdhj*hdih*hdji-gdhj*hdjh*hdii)

# %%
#zz
# if False:
ss = (spin("i").y * spin("j").y).simplify()
print(ss.wickcode())
print("---")
ss = (den("i") * den("j")).simplify()
print(ss.wickcode())
print("---")
# test = c("u", "1", 1)*c("u", "2")*c("u", "3", 1)*c("u", "4")*c("u", "5", 1)*c("u", "6")
# print(test.wickstr())
# Out:
# +1*(+huji*gdij)
# +1*(+hdji*guij)
# ---
# +1*(+huii*hujj+huji*guij)
# +1*(+huii*hdjj)
# +1*(+hdii*hujj)
# +1*(+hdii*hdjj+hdji*gdij)
# ---

# %%
#eq10
se = spin("e")
sj = spin("j")
sk = spin("k")
sss = se.dot(sj.cross(sk)).simplify()
eq10 = (-1j*c("u", "d")*c("u", "i", 1)*sss).simplify()
#print(eq10)
#print("---")
#print(eq10.wickstr())
print(eq10.wickcode())
# Out:
# +2*(-gude*huei*hukj*gdjk-gude*huki*guej*gdjk+gudi*huee*hukj*gdjk+gudi*huke*guej*gdjk+gudj*huei*huke*gdjk-gudj*huki*huee*gdjk)
# -2*(-gude*huei*hdkj*gujk+gude*huji*guek*hdkj+gudi*huee*hdkj*gujk-gudi*huje*guek*hdkj-gudk*huei*huje*hdkj+gudk*huji*huee*hdkj)
# -2*(+gude*huji*gdek*hukj-gude*huki*gdek*hujj-gudi*huje*gdek*hukj+gudi*huke*gdek*hujj-gudj*huji*huke*gdek+gudj*huki*huje*gdek)
# +2*(-gude*huji*gdej*hukk-gude*huki*gdej*gujk+gudi*huje*gdej*hukk+gudi*huke*gdej*gujk+gudk*huji*huke*gdej-gudk*huki*huje*gdej)
# -2*(-gude*huji*gdej*hdkk+gude*huji*gdek*hdkj+gudi*huje*gdej*hdkk-gudi*huje*gdek*hdkj)
# +2*(-gude*huki*gdej*gdjk-gude*huki*gdek*hdjj+gudi*huke*gdej*gdjk+gudi*huke*gdek*hdjj)
# +2*(+gudi*hdke*guej*gujk+gudi*hdke*guek*hujj+gudj*huei*hdke*gujk-gudj*huji*hdke*guek+gudk*huei*hdke*hujj+gudk*huji*hdke*guej)
# -2*(+gudi*hdje*guej*hukk-gudi*hdje*guek*hukj+gudj*huei*hdje*hukk+gudj*huki*hdje*guek-gudk*huei*hdje*hukj-gudk*huki*hdje*guej)
# +2*(+gudi*hdje*guej*hdkk+gudi*hdke*guej*gdjk+gudj*huei*hdje*hdkk+gudj*huei*hdke*gdjk)
# -2*(-gudi*hdje*guek*hdkj+gudi*hdke*guek*hdjj-gudk*huei*hdje*hdkj+gudk*huei*hdke*hdjj)
# -2*(+gudi*hdee*hukj*gdjk-gudi*hdje*gdek*hukj-gudj*huki*hdee*gdjk+gudj*huki*hdje*gdek)
# +2*(+gudi*hdee*hdkj*gujk+gudi*hdke*gdej*gujk+gudk*huji*hdee*hdkj+gudk*huji*hdke*gdej)

# %%
#eq4
si = spin("i")
sj = spin("j")
sk = spin("k")
ssss = ((si.dot(sj))*(si.dot(sk))).simplify()
eq4 = (c("u", "h")*c("u", "h", 1)*ssss).simplify()
print(eq4.wickcode())
# Out:
# +1*(+guhh*huii*guii*hujj*hukk+guhh*huii*guii*hukj*gujk+guhh*huii*guij*guji*hukk-guhh*huii*guij*gujk*huki-guhh*huii*guik*hujj*huki-guhh*huii*guik*hukj*guji+guhh*huii*huij*guji*hukk-guhh*huii*huij*gujk*huki+guhh*huii*hujj*huii*hukk+guhh*huii*hujj*huki*guik+guhh*huii*hukj*guji*guik+guhh*huii*hukj*gujk*huii-guhh*huji*guii*huij*hukk-guhh*huji*guii*hukj*guik+guhh*huji*guij*huii*hukk+guhh*huji*guij*huki*guik+guhh*huji*guik*huij*huki-guhh*huji*guik*hukj*huii-guhh*huki*guii*huij*gujk+guhh*huki*guii*hujj*guik+guhh*huki*guij*guji*guik+guhh*huki*guij*gujk*huii+guhh*huki*guik*huij*guji+guhh*huki*guik*hujj*huii-guhi*huih*guii*hujj*hukk-guhi*huih*guii*hukj*gujk-guhi*huih*guij*guji*hukk+guhi*huih*guij*gujk*huki+guhi*huih*guik*hujj*huki+guhi*huih*guik*hukj*guji-guhi*huih*huji*guij*hukk+guhi*huih*huji*guik*hukj-guhi*huih*huji*huij*hukk-guhi*huih*huji*hukj*guik-guhi*huih*huki*guij*gujk-guhi*huih*huki*guik*hujj-guhi*huih*huki*huij*gujk+guhi*huih*huki*hujj*guik-guhi*huih*huij*guji*hukk+guhi*huih*huij*gujk*huki-guhi*huih*hujj*huii*hukk-guhi*huih*hujj*huki*guik-guhi*huih*hukj*guji*guik-guhi*huih*hukj*gujk*huii+guhi*hujh*guii*huij*hukk+guhi*hujh*guii*hukj*guik-guhi*hujh*guij*huii*hukk-guhi*hujh*guij*huki*guik-guhi*hujh*guik*huij*huki+guhi*hujh*guik*hukj*huii+guhi*hujh*huii*guij*hukk-guhi*hujh*huii*guik*hukj+guhi*hujh*huii*huij*hukk+guhi*hujh*huii*hukj*guik+guhi*hujh*huki*guij*guik+guhi*hujh*huki*guik*huij+guhi*hukh*guii*huij*gujk-guhi*hukh*guii*hujj*guik-guhi*hukh*guij*guji*guik-guhi*hukh*guij*gujk*huii-guhi*hukh*guik*huij*guji-guhi*hukh*guik*hujj*huii+guhi*hukh*huii*guij*gujk+guhi*hukh*huii*guik*hujj+guhi*hukh*huii*huij*gujk-guhi*hukh*huii*hujj*guik-guhi*hukh*huji*guij*guik-guhi*hukh*huji*guik*huij+guhj*huih*huji*guii*hukk-guhj*huih*huji*guik*huki+guhj*huih*huji*huii*hukk+guhj*huih*huji*huki*guik+guhj*huih*huki*guii*gujk-guhj*huih*huki*guik*guji+guhj*huih*huki*guji*guik+guhj*huih*huki*gujk*huii-guhj*hujh*huii*guii*hukk+guhj*hujh*huii*guik*huki-guhj*hujh*huii*huii*hukk-guhj*hujh*huii*huki*guik-guhj*hujh*huki*guii*guik-guhj*hujh*huki*guik*huii-guhj*hukh*huii*guii*gujk+guhj*hukh*huii*guik*guji-guhj*hukh*huii*guji*guik-guhj*hukh*huii*gujk*huii+guhj*hukh*huji*guii*guik+guhj*hukh*huji*guik*huii-guhk*huih*huji*guii*hukj+guhk*huih*huji*guij*huki+guhk*huih*huji*huij*huki-guhk*huih*huji*hukj*huii+guhk*huih*huki*guii*hujj+guhk*huih*huki*guij*guji+guhk*huih*huki*huij*guji+guhk*huih*huki*hujj*huii+guhk*hujh*huii*guii*hukj-guhk*hujh*huii*guij*huki-guhk*hujh*huii*huij*huki+guhk*hujh*huii*hukj*huii-guhk*hujh*huki*guii*huij+guhk*hujh*huki*guij*huii-guhk*hukh*huii*guii*hujj-guhk*hukh*huii*guij*guji-guhk*hukh*huii*huij*guji-guhk*hukh*huii*hujj*huii+guhk*hukh*huji*guii*huij-guhk*hukh*huji*guij*huii)
# -1*(+guhh*huii*guii*hujj*hdkk+guhh*huii*guij*guji*hdkk+guhh*huii*huij*guji*hdkk+guhh*huii*hujj*huii*hdkk-guhh*huji*guii*huij*hdkk+guhh*huji*guij*huii*hdkk-guhi*huih*guii*hujj*hdkk-guhi*huih*guij*guji*hdkk-guhi*huih*huji*guij*hdkk-guhi*huih*huji*huij*hdkk-guhi*huih*huij*guji*hdkk-guhi*huih*hujj*huii*hdkk+guhi*hujh*guii*huij*hdkk-guhi*hujh*guij*huii*hdkk+guhi*hujh*huii*guij*hdkk+guhi*hujh*huii*huij*hdkk+guhj*huih*huji*guii*hdkk+guhj*huih*huji*huii*hdkk-guhj*hujh*huii*guii*hdkk-guhj*hujh*huii*huii*hdkk)
# +2*(+guhh*huii*hujj*huki*gdik+guhh*huii*hukj*guji*gdik-guhh*huji*guii*hukj*gdik+guhh*huji*guij*huki*gdik+guhh*huki*guii*hujj*gdik+guhh*huki*guij*guji*gdik-guhi*huih*huji*hukj*gdik+guhi*huih*huki*hujj*gdik-guhi*huih*hujj*huki*gdik-guhi*huih*hukj*guji*gdik+guhi*hujh*guii*hukj*gdik-guhi*hujh*guij*huki*gdik+guhi*hujh*huii*hukj*gdik+guhi*hujh*huki*guij*gdik-guhi*hukh*guii*hujj*gdik-guhi*hukh*guij*guji*gdik-guhi*hukh*huii*hujj*gdik-guhi*hukh*huji*guij*gdik+guhj*huih*huji*huki*gdik+guhj*huih*huki*guji*gdik-guhj*hujh*huii*huki*gdik-guhj*hujh*huki*guii*gdik-guhj*hukh*huii*guji*gdik+guhj*hukh*huji*guii*gdik)
# +2*(-guhh*huii*guij*gujk*hdki-guhh*huii*guik*hujj*hdki-guhh*huii*huij*gujk*hdki+guhh*huii*hujj*hdki*guik+guhh*huji*guij*hdki*guik+guhh*huji*guik*huij*hdki+guhi*huih*guij*gujk*hdki+guhi*huih*guik*hujj*hdki+guhi*huih*huij*gujk*hdki-guhi*huih*hujj*hdki*guik-guhi*hujh*guij*hdki*guik-guhi*hujh*guik*huij*hdki-guhj*huih*huji*guik*hdki+guhj*huih*huji*hdki*guik+guhj*hujh*huii*guik*hdki-guhj*hujh*huii*hdki*guik+guhk*huih*huji*guij*hdki+guhk*huih*huji*huij*hdki-guhk*hujh*huii*guij*hdki-guhk*hujh*huii*huij*hdki)
# -1*(+guhh*huii*hujj*hdii*hukk+guhh*huii*hukj*gujk*hdii+guhh*huji*guij*hdii*hukk-guhh*huji*guik*hukj*hdii+guhh*huki*guij*gujk*hdii+guhh*huki*guik*hujj*hdii-guhi*huih*hujj*hdii*hukk-guhi*huih*hukj*gujk*hdii-guhi*hujh*guij*hdii*hukk+guhi*hujh*guik*hukj*hdii-guhi*hukh*guij*gujk*hdii-guhi*hukh*guik*hujj*hdii+guhj*huih*huji*hdii*hukk+guhj*huih*huki*gujk*hdii-guhj*hujh*huii*hdii*hukk-guhj*hujh*huki*guik*hdii-guhj*hukh*huii*gujk*hdii+guhj*hukh*huji*guik*hdii-guhk*huih*huji*hukj*hdii+guhk*huih*huki*hujj*hdii+guhk*hujh*huii*hukj*hdii+guhk*hujh*huki*guij*hdii-guhk*hukh*huii*hujj*hdii-guhk*hukh*huji*guij*hdii)
# +1*(+guhh*huii*hujj*hdii*hdkk+guhh*huii*hujj*hdki*gdik+guhh*huji*guij*hdii*hdkk+guhh*huji*guij*hdki*gdik-guhi*huih*hujj*hdii*hdkk-guhi*huih*hujj*hdki*gdik-guhi*hujh*guij*hdii*hdkk-guhi*hujh*guij*hdki*gdik+guhj*huih*huji*hdii*hdkk+guhj*huih*huji*hdki*gdik-guhj*hujh*huii*hdii*hdkk-guhj*hujh*huii*hdki*gdik)
# -1*(+guhh*huii*guii*hdjj*hukk-guhh*huii*guik*hdjj*huki+guhh*huii*hdjj*huii*hukk+guhh*huii*hdjj*huki*guik+guhh*huki*guii*hdjj*guik+guhh*huki*guik*hdjj*huii-guhi*huih*guii*hdjj*hukk+guhi*huih*guik*hdjj*huki-guhi*huih*huki*guik*hdjj+guhi*huih*huki*hdjj*guik-guhi*huih*hdjj*huii*hukk-guhi*huih*hdjj*huki*guik-guhi*hukh*guii*hdjj*guik-guhi*hukh*guik*hdjj*huii+guhi*hukh*huii*guik*hdjj-guhi*hukh*huii*hdjj*guik+guhk*huih*huki*guii*hdjj+guhk*huih*huki*hdjj*huii-guhk*hukh*huii*guii*hdjj-guhk*hukh*huii*hdjj*huii)
# +1*(+guhh*huii*guii*hdjj*hdkk+guhh*huii*guii*hdkj*gdjk+guhh*huii*hdjj*huii*hdkk+guhh*huii*hdkj*gdjk*huii-guhi*huih*guii*hdjj*hdkk-guhi*huih*guii*hdkj*gdjk-guhi*huih*hdjj*huii*hdkk-guhi*huih*hdkj*gdjk*huii)
# -2*(-guhh*huii*hdij*gdjk*huki+guhh*huii*hdjj*huki*gdik-guhh*huki*guii*hdij*gdjk+guhh*huki*guii*hdjj*gdik-guhi*huih*huki*hdij*gdjk+guhi*huih*huki*hdjj*gdik+guhi*huih*hdij*gdjk*huki-guhi*huih*hdjj*huki*gdik+guhi*hukh*guii*hdij*gdjk-guhi*hukh*guii*hdjj*gdik+guhi*hukh*huii*hdij*gdjk-guhi*hukh*huii*hdjj*gdik)
# -2*(-guhh*huii*guik*hdjj*hdki-guhh*huii*guik*hdkj*gdji+guhh*huii*hdjj*hdki*guik+guhh*huii*hdkj*gdji*guik+guhi*huih*guik*hdjj*hdki+guhi*huih*guik*hdkj*gdji-guhi*huih*hdjj*hdki*guik-guhi*huih*hdkj*gdji*guik)
# +1*(+guhh*huii*hdij*gdji*hukk+guhh*huii*hdjj*hdii*hukk+guhh*huki*guik*hdij*gdji+guhh*huki*guik*hdjj*hdii-guhi*huih*hdij*gdji*hukk-guhi*huih*hdjj*hdii*hukk-guhi*hukh*guik*hdij*gdji-guhi*hukh*guik*hdjj*hdii+guhk*huih*huki*hdij*gdji+guhk*huih*huki*hdjj*hdii-guhk*hukh*huii*hdij*gdji-guhk*hukh*huii*hdjj*hdii)
# -1*(+guhh*huii*hdij*gdji*hdkk-guhh*huii*hdij*gdjk*hdki+guhh*huii*hdjj*hdii*hdkk+guhh*huii*hdjj*hdki*gdik+guhh*huii*hdkj*gdji*gdik+guhh*huii*hdkj*gdjk*hdii-guhi*huih*hdij*gdji*hdkk+guhi*huih*hdij*gdjk*hdki-guhi*huih*hdjj*hdii*hdkk-guhi*huih*hdjj*hdki*gdik-guhi*huih*hdkj*gdji*gdik-guhi*huih*hdkj*gdjk*hdii)
# +2*(+guhh*huii*gdij*guji*hukk-guhh*huii*gdij*gujk*huki+guhh*huji*gdij*huii*hukk+guhh*huji*gdij*huki*guik+guhh*huki*gdij*guji*guik+guhh*huki*gdij*gujk*huii-guhi*huih*huji*gdij*hukk-guhi*huih*huki*gdij*gujk-guhi*huih*gdij*guji*hukk+guhi*huih*gdij*gujk*huki+guhi*hujh*huii*gdij*hukk+guhi*hujh*huki*gdij*guik-guhi*hujh*gdij*huii*hukk-guhi*hujh*gdij*huki*guik+guhi*hukh*huii*gdij*gujk-guhi*hukh*huji*gdij*guik-guhi*hukh*gdij*guji*guik-guhi*hukh*gdij*gujk*huii+guhk*huih*huji*gdij*huki+guhk*huih*huki*gdij*guji-guhk*hujh*huii*gdij*huki+guhk*hujh*huki*gdij*huii-guhk*hukh*huii*gdij*guji-guhk*hukh*huji*gdij*huii)
# -2*(+guhh*huii*gdij*guji*hdkk-guhh*huii*gdik*hdkj*guji+guhh*huji*gdij*huii*hdkk-guhh*huji*gdik*hdkj*huii-guhi*huih*huji*gdij*hdkk+guhi*huih*huji*gdik*hdkj-guhi*huih*gdij*guji*hdkk+guhi*huih*gdik*hdkj*guji+guhi*hujh*huii*gdij*hdkk-guhi*hujh*huii*gdik*hdkj-guhi*hujh*gdij*huii*hdkk+guhi*hujh*gdik*hdkj*huii)
# +4*(+guhh*huji*gdij*huki*gdik+guhh*huji*gdik*hdij*huki+guhh*huki*gdij*guji*gdik+guhh*huki*gdik*hdij*guji+guhi*hujh*huki*gdij*gdik+guhi*hujh*huki*gdik*hdij-guhi*hujh*gdij*huki*gdik-guhi*hujh*gdik*hdij*huki-guhi*hukh*huji*gdij*gdik-guhi*hukh*huji*gdik*hdij-guhi*hukh*gdij*guji*gdik-guhi*hukh*gdik*hdij*guji)
# +4*(+guhh*huii*gdii*hdkj*gujk-guhh*huii*gdij*gujk*hdki-guhh*huji*gdii*hdkj*guik+guhh*huji*gdij*hdki*guik-guhi*huih*gdii*hdkj*gujk+guhi*huih*gdij*gujk*hdki+guhi*hujh*gdii*hdkj*guik-guhi*hujh*gdij*hdki*guik-guhk*huih*huji*gdii*hdkj+guhk*huih*huji*gdij*hdki+guhk*hujh*huii*gdii*hdkj-guhk*hujh*huii*gdij*hdki)
# -2*(-guhh*huji*gdii*hdij*hukk+guhh*huji*gdij*hdii*hukk-guhh*huki*gdii*hdij*gujk+guhh*huki*gdij*gujk*hdii+guhi*hujh*gdii*hdij*hukk-guhi*hujh*gdij*hdii*hukk+guhi*hukh*gdii*hdij*gujk-guhi*hukh*gdij*gujk*hdii-guhk*hujh*huki*gdii*hdij+guhk*hujh*huki*gdij*hdii+guhk*hukh*huji*gdii*hdij-guhk*hukh*huji*gdij*hdii)
# +2*(-guhh*huji*gdii*hdij*hdkk-guhh*huji*gdii*hdkj*gdik+guhh*huji*gdij*hdii*hdkk+guhh*huji*gdij*hdki*gdik+guhh*huji*gdik*hdij*hdki-guhh*huji*gdik*hdkj*hdii+guhi*hujh*gdii*hdij*hdkk+guhi*hujh*gdii*hdkj*gdik-guhi*hujh*gdij*hdii*hdkk-guhi*hujh*gdij*hdki*gdik-guhi*hujh*gdik*hdij*hdki+guhi*hujh*gdik*hdkj*hdii)
# +2*(-guhh*hdji*guii*huij*hukk-guhh*hdji*guii*hukj*guik+guhh*hdji*guij*huii*hukk+guhh*hdji*guij*huki*guik+guhh*hdji*guik*huij*huki-guhh*hdji*guik*hukj*huii-guhi*huih*hdji*guij*hukk+guhi*huih*hdji*guik*hukj-guhi*huih*hdji*huij*hukk-guhi*huih*hdji*hukj*guik-guhi*hukh*hdji*guij*guik-guhi*hukh*hdji*guik*huij+guhj*huih*hdji*guii*hukk-guhj*huih*hdji*guik*huki+guhj*huih*hdji*huii*hukk+guhj*huih*hdji*huki*guik+guhj*hukh*hdji*guii*guik+guhj*hukh*hdji*guik*huii-guhk*huih*hdji*guii*hukj+guhk*huih*hdji*guij*huki+guhk*huih*hdji*huij*huki-guhk*huih*hdji*hukj*huii+guhk*hukh*hdji*guii*huij-guhk*hukh*hdji*guij*huii)
# -2*(-guhh*hdji*guii*huij*hdkk+guhh*hdji*guij*huii*hdkk-guhh*hdki*guii*huij*gdjk+guhh*hdki*guij*gdjk*huii-guhi*huih*hdji*guij*hdkk-guhi*huih*hdji*huij*hdkk-guhi*huih*hdki*guij*gdjk-guhi*huih*hdki*huij*gdjk+guhj*huih*hdji*guii*hdkk+guhj*huih*hdji*huii*hdkk+guhj*huih*hdki*guii*gdjk+guhj*huih*hdki*gdjk*huii)
# +4*(+guhh*hdii*guii*hukj*gdjk-guhh*hdii*guij*gdjk*huki-guhh*hdji*guii*hukj*gdik+guhh*hdji*guij*huki*gdik+guhi*huih*hdii*hukj*gdjk-guhi*huih*hdji*hukj*gdik+guhi*hukh*hdii*guij*gdjk-guhi*hukh*hdji*guij*gdik-guhj*huih*hdii*gdjk*huki+guhj*huih*hdji*huki*gdik-guhj*hukh*hdii*guii*gdjk+guhj*hukh*hdji*guii*gdik)
# +4*(+guhh*hdji*guij*hdki*guik+guhh*hdji*guik*huij*hdki+guhh*hdki*guij*gdji*guik+guhh*hdki*guik*huij*gdji-guhj*huih*hdji*guik*hdki+guhj*huih*hdji*hdki*guik-guhj*huih*hdki*guik*gdji+guhj*huih*hdki*gdji*guik+guhk*huih*hdji*guij*hdki+guhk*huih*hdji*huij*hdki+guhk*huih*hdki*guij*gdji+guhk*huih*hdki*huij*gdji)
# -2*(+guhh*hdii*guij*gdji*hukk-guhh*hdii*guik*hukj*gdji+guhh*hdji*guij*hdii*hukk-guhh*hdji*guik*hukj*hdii+guhj*huih*hdii*gdji*hukk+guhj*huih*hdji*hdii*hukk+guhj*hukh*hdii*guik*gdji+guhj*hukh*hdji*guik*hdii-guhk*huih*hdii*hukj*gdji-guhk*huih*hdji*hukj*hdii-guhk*hukh*hdii*guij*gdji-guhk*hukh*hdji*guij*hdii)
# +2*(+guhh*hdii*guij*gdji*hdkk-guhh*hdii*guij*gdjk*hdki+guhh*hdji*guij*hdii*hdkk+guhh*hdji*guij*hdki*gdik+guhh*hdki*guij*gdji*gdik+guhh*hdki*guij*gdjk*hdii+guhj*huih*hdii*gdji*hdkk-guhj*huih*hdii*gdjk*hdki+guhj*huih*hdji*hdii*hdkk+guhj*huih*hdji*hdki*gdik+guhj*huih*hdki*gdji*gdik+guhj*huih*hdki*gdjk*hdii)
# -1*(+guhh*hdii*huij*guji*hukk-guhh*hdii*huij*gujk*huki+guhh*hdii*hujj*huii*hukk+guhh*hdii*hujj*huki*guik+guhh*hdii*hukj*guji*guik+guhh*hdii*hukj*gujk*huii-guhi*huih*hdii*hujj*hukk-guhi*huih*hdii*hukj*gujk+guhi*hujh*hdii*huij*hukk+guhi*hujh*hdii*hukj*guik+guhi*hukh*hdii*huij*gujk-guhi*hukh*hdii*hujj*guik-guhj*huih*hdii*guji*hukk+guhj*huih*hdii*gujk*huki-guhj*hujh*hdii*huii*hukk-guhj*hujh*hdii*huki*guik-guhj*hukh*hdii*guji*guik-guhj*hukh*hdii*gujk*huii+guhk*huih*hdii*hujj*huki+guhk*huih*hdii*hukj*guji-guhk*hujh*hdii*huij*huki+guhk*hujh*hdii*hukj*huii-guhk*hukh*hdii*huij*guji-guhk*hukh*hdii*hujj*huii)
# +1*(+guhh*hdii*huij*guji*hdkk+guhh*hdii*hujj*huii*hdkk+guhh*hdki*gdik*huij*guji+guhh*hdki*gdik*hujj*huii-guhi*huih*hdii*hujj*hdkk-guhi*huih*hdki*gdik*hujj+guhi*hujh*hdii*huij*hdkk+guhi*hujh*hdki*gdik*huij-guhj*huih*hdii*guji*hdkk-guhj*huih*hdki*gdik*guji-guhj*hujh*hdii*huii*hdkk-guhj*hujh*hdki*gdik*huii)
# -2*(-guhh*hdii*gdik*hujj*huki-guhh*hdii*gdik*hukj*guji+guhh*hdii*hujj*huki*gdik+guhh*hdii*hukj*guji*gdik-guhi*hujh*hdii*gdik*hukj+guhi*hujh*hdii*hukj*gdik+guhi*hukh*hdii*gdik*hujj-guhi*hukh*hdii*hujj*gdik+guhj*hujh*hdii*gdik*huki-guhj*hujh*hdii*huki*gdik+guhj*hukh*hdii*gdik*guji-guhj*hukh*hdii*guji*gdik)
# -2*(-guhh*hdii*huij*gujk*hdki+guhh*hdii*hujj*hdki*guik-guhh*hdki*gdii*huij*gujk+guhh*hdki*gdii*hujj*guik+guhj*huih*hdii*gujk*hdki+guhj*huih*hdki*gdii*gujk-guhj*hujh*hdii*hdki*guik-guhj*hujh*hdki*gdii*guik+guhk*huih*hdii*hujj*hdki+guhk*huih*hdki*gdii*hujj-guhk*hujh*hdii*huij*hdki-guhk*hujh*hdki*gdii*huij)
# +1*(+guhh*hdii*gdii*hujj*hukk+guhh*hdii*gdii*hukj*gujk+guhh*hdii*hujj*hdii*hukk+guhh*hdii*hukj*gujk*hdii-guhj*hujh*hdii*gdii*hukk-guhj*hujh*hdii*hdii*hukk-guhj*hukh*hdii*gdii*gujk-guhj*hukh*hdii*gujk*hdii+guhk*hujh*hdii*gdii*hukj+guhk*hujh*hdii*hukj*hdii-guhk*hukh*hdii*gdii*hujj-guhk*hukh*hdii*hujj*hdii)
# -1*(+guhh*hdii*gdii*hujj*hdkk-guhh*hdii*gdik*hujj*hdki+guhh*hdii*hujj*hdii*hdkk+guhh*hdii*hujj*hdki*gdik+guhh*hdki*gdii*hujj*gdik+guhh*hdki*gdik*hujj*hdii-guhj*hujh*hdii*gdii*hdkk+guhj*hujh*hdii*gdik*hdki-guhj*hujh*hdii*hdii*hdkk-guhj*hujh*hdii*hdki*gdik-guhj*hujh*hdki*gdii*gdik-guhj*hujh*hdki*gdik*hdii)
# +1*(+guhh*hdii*hdjj*huii*hukk+guhh*hdii*hdjj*huki*guik+guhh*hdji*gdij*huii*hukk+guhh*hdji*gdij*huki*guik-guhi*huih*hdii*hdjj*hukk-guhi*huih*hdji*gdij*hukk-guhi*hukh*hdii*hdjj*guik-guhi*hukh*hdji*gdij*guik+guhk*huih*hdii*hdjj*huki+guhk*huih*hdji*gdij*huki-guhk*hukh*hdii*hdjj*huii-guhk*hukh*hdji*gdij*huii)
# -1*(+guhh*hdii*hdjj*huii*hdkk+guhh*hdii*hdkj*gdjk*huii+guhh*hdji*gdij*huii*hdkk-guhh*hdji*gdik*hdkj*huii+guhh*hdki*gdij*gdjk*huii+guhh*hdki*gdik*hdjj*huii-guhi*huih*hdii*hdjj*hdkk-guhi*huih*hdii*hdkj*gdjk-guhi*huih*hdji*gdij*hdkk+guhi*huih*hdji*gdik*hdkj-guhi*huih*hdki*gdij*gdjk-guhi*huih*hdki*gdik*hdjj)
# +2*(-guhh*hdii*gdij*gdjk*huki-guhh*hdii*gdik*hdjj*huki-guhh*hdii*hdij*gdjk*huki+guhh*hdii*hdjj*huki*gdik+guhh*hdji*gdij*huki*gdik+guhh*hdji*gdik*hdij*huki+guhi*hukh*hdii*gdij*gdjk+guhi*hukh*hdii*gdik*hdjj+guhi*hukh*hdii*hdij*gdjk-guhi*hukh*hdii*hdjj*gdik-guhi*hukh*hdji*gdij*gdik-guhi*hukh*hdji*gdik*hdij)
# +2*(+guhh*hdii*hdjj*hdki*guik+guhh*hdii*hdkj*gdji*guik-guhh*hdji*gdii*hdkj*guik+guhh*hdji*gdij*hdki*guik+guhh*hdki*gdii*hdjj*guik+guhh*hdki*gdij*gdji*guik+guhk*huih*hdii*hdjj*hdki+guhk*huih*hdii*hdkj*gdji-guhk*huih*hdji*gdii*hdkj+guhk*huih*hdji*gdij*hdki+guhk*huih*hdki*gdii*hdjj+guhk*huih*hdki*gdij*gdji)
# -1*(+guhh*hdii*gdii*hdjj*hukk+guhh*hdii*gdij*gdji*hukk+guhh*hdii*hdij*gdji*hukk+guhh*hdii*hdjj*hdii*hukk-guhh*hdji*gdii*hdij*hukk+guhh*hdji*gdij*hdii*hukk-guhk*hukh*hdii*gdii*hdjj-guhk*hukh*hdii*gdij*gdji-guhk*hukh*hdii*hdij*gdji-guhk*hukh*hdii*hdjj*hdii+guhk*hukh*hdji*gdii*hdij-guhk*hukh*hdji*gdij*hdii)
# +1*(+guhh*hdii*gdii*hdjj*hdkk+guhh*hdii*gdii*hdkj*gdjk+guhh*hdii*gdij*gdji*hdkk-guhh*hdii*gdij*gdjk*hdki-guhh*hdii*gdik*hdjj*hdki-guhh*hdii*gdik*hdkj*gdji+guhh*hdii*hdij*gdji*hdkk-guhh*hdii*hdij*gdjk*hdki+guhh*hdii*hdjj*hdii*hdkk+guhh*hdii*hdjj*hdki*gdik+guhh*hdii*hdkj*gdji*gdik+guhh*hdii*hdkj*gdjk*hdii-guhh*hdji*gdii*hdij*hdkk-guhh*hdji*gdii*hdkj*gdik+guhh*hdji*gdij*hdii*hdkk+guhh*hdji*gdij*hdki*gdik+guhh*hdji*gdik*hdij*hdki-guhh*hdji*gdik*hdkj*hdii-guhh*hdki*gdii*hdij*gdjk+guhh*hdki*gdii*hdjj*gdik+guhh*hdki*gdij*gdji*gdik+guhh*hdki*gdij*gdjk*hdii+guhh*hdki*gdik*hdij*gdji+guhh*hdki*gdik*hdjj*hdii)
